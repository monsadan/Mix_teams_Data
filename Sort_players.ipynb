# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
jugadores = pd.read_excel('jugadores.xlsx', engine='openpyxl')

# %%
print(jugadores.shape)
# Out:
# (112, 7)

# %%
jugadores.head()
# Out:
#      Jugador      Fecha Posición  Gol  Gol Favor  Gol Contra  Equipo
# 0  Jugador 1 2021-10-04       AR    2         13          13       1
# 1  Jugador 2 2021-10-04       DF    2         13          13       1
# 2  Jugador 3 2021-10-04       DF    2         13          13       1
# 3  Jugador 4 2021-10-04       DF    2         13          13       1
# 4  Jugador 5 2021-10-04       MC    0         13          13       1

# %%
sns.lineplot(data=jugadores, x='Fecha', y='Gol', hue='Equipo', palette='tab10')
